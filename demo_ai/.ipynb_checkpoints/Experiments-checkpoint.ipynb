# %%
data = {
    'x' : [100.0,200.0,300.0,400.0,500.0],
    'y' : [100.0,200.0,300.0,400.0,500.0],
}
data
# Out:
# {'x': [100.0, 200.0, 300.0, 400.0, 500.0],
#  'y': [100.0, 200.0, 300.0, 400.0, 500.0]}

# %%
for i in range(len(data['x'])):
    data['x'][i] = data['x'][i] /100
    data['y'][i] = data['y'][i] / 100

data
# Out:
# {'x': [100.0, 200.0, 300.0, 400.0, 500.0],
#  'y': [100.0, 200.0, 300.0, 400.0, 500.0]}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[245], line 4
#       1 display(data)
#       3 for i in range(len(data['x'])):
# ----> 4     data['x'] = data['x'][i] /100
#       5     data['y'] = data['y'][i] / 100
#       7 data
#
# TypeError: 'float' object is not subscriptable

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(np.array(data['x']), np.array(data['y']))
plt.show()

# %%
def linear(param_m, param_x, param_c):
    return (param_m * param_x) + param_c

m = 2
c = 1

def get_ypredict(data_x):
    result = []
    for i in range(len(data_x)):
        y_predict = linear(m, data_x[i], c)
        result.append(y_predict)

    return result

list_y_predict = get_ypredict(data['x'])


fig, ax = plt.subplots()
ax.plot(np.array(data['x']), np.array(list_y_predict))
plt.show()

# %%
def get_y_pred_and_error(data_x, data_y):
    result = []
    for i in range(len(data_x)):
        y_predict = linear(m, data_x[i], c)
        result.append({
            'predict': y_predict,
            'error': abs(data_y[i] - y_predict)
        })

    return result

get_y_pred_and_error(data['x'], data['y'])
# Out:
# [{'predict': 201, 'error': 101},
#  {'predict': 401, 'error': 201},
#  {'predict': 601, 'error': 301},
#  {'predict': 801, 'error': 401},
#  {'predict': 1001, 'error': 501}]

# %%
def get_y_pred_and_error(data_x, data_y, param_m, param_c ):
    result = []
    total_error_pangkat2 = 0
    total_error = 0
    total_ereror_reg = 0
    for i in range(len(data_x)):
        y_predict = linear(param_m, data_x[i], param_c)
        
        result.append({
            'predict': y_predict,
            'error': abs(data_y[i] - y_predict)
        })
        total_error_pangkat2 = total_error_pangkat2 + pow(data_y[i] - y_predict, 2)
        total_error = total_error_pangkat2 + (data_y[i] - y_predict)
        
    return result, total_error_pangkat2, total_error

get_y_pred_and_error(data['x'], data['y'], 2, 1)
# Out:
# ([{'predict': 201, 'error': 101},
#   {'predict': 401, 'error': 201},
#   {'predict': 601, 'error': 301},
#   {'predict': 801, 'error': 401},
#   {'predict': 1001, 'error': 501}],
#  553005,
#  552504)

# %%
def gradient_descent():
    mse = 100
    error_max = 0.01
    iteration = 0
    m = 2
    c = 0.3
    while(mse > error_max and iteration < 100):
        result, total_error_pangkat2, total_error = get_y_pred_and_error(data['x'], data['y'], m, c)
        mse = total_error_pangkat2 / (2 * len(data['x']))
        delta_error = total_error / len(data['x'])
        m = m - 0.01 * delta_error
        c = c - 0.01 * delta_error
        iteration = iteration + 1

    return m, c

gradient_descent()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[207], line 17
#      13         iteration = iteration + 1
#      15     return m, c
# ---> 17 gradient_descent()
#
# Cell In[207], line 8, in gradient_descent()
#       6 c = 0.3
#       7 while(mse > error_max and iteration < 100):
# ----> 8     result, total_error_pangkat2, total_error = get_y_pred_and_error(data['x'], data['y'], m, c)
#       9     mse = total_error_pangkat2 / (2 * len(data['x']))
#      10     delta_error = total_error / len(data['x'])
#
# Cell In[204], line 13, in get_y_pred_and_error(data_x, data_y, param_m, param_c)
#       7     y_predict = linear(param_m, data_x[i], param_c)
#       9     result.append({
#      10         'predict': y_predict,
#      11         'error': abs(data_y[i] - y_predict)
#      12     })
# ---> 13     total_error_pangkat2 = total_error_pangkat2 + pow(data_y[i] - y_predict, 2)
#      14     total_error = total_error_pangkat2 + (data_y[i] - y_predict)
#      16 return result, total_error_pangkat2, total_error
#
# OverflowError: (34, 'Numerical result out of range')

# %%
get_y_pred_and_error(data['x'], data['y'], 1.24,-0.45 )
# Out:
# ([{'predict': 123.55, 'error': 23.549999999999997},
#   {'predict': 247.55, 'error': 47.55000000000001},
#   {'predict': 371.55, 'error': 71.55000000000001},
#   {'predict': 495.55, 'error': 95.55000000000001},
#   {'predict': 619.55, 'error': 119.54999999999995}],
#  31357.012499999993,
#  31237.462499999994)
